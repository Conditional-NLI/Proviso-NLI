# %%
import pandas as pd
import pickle

from dataset import NewsDataset
from smooth_gradient import SmoothGradient
from integrated_gradient import IntegratedGradient

from collections import defaultdict
import string

import torch
from torch import nn
from torch.utils.data import DataLoader
from transformers import DistilBertConfig, DistilBertTokenizer
from transformers import RobertaConfig

from IPython.display import display, HTML

from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForSequenceClassification, DataCollatorWithPadding

# %%
from huggingface_hub import login

login(new_session=False, # Won’t request token if one is already saved on machine
write_permission=True, # Requires a token with write permission
token="", # The name of your token
add_to_git_credential=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in 'login': write_permission. Will not be supported from version '1.0'.
#
# Fine-grained tokens added complexity to the permissions, making it irrelevant to check if a token has 'write' access.
#   warnings.warn(message, FutureWarning)
# Token has not been saved to git credential helper.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.

# %%
checkpoint = "ConditionalNLI/Exp5_roberta-large-mnli"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=3)

# %%
config = RobertaConfig()
batch_size = 4
criterion = nn.CrossEntropyLoss()
config.max_position_embeddings
# Out:
# 512

# %% [markdown]
# ## Running on Dataset

# %%
from datasets import load_dataset, concatenate_datasets
import json
import ast

# %%
test_df4 = pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type4_final.csv',index_col=0)
test_df4
# Out:
#                                                premise  \
# 0        Liam believes that his wind tunnel is nearby.
# 1    If Liam is an aerospace engineer and he tests ...
# 2    Either Liam isn't an aerospace engineer, or he...
# 3    If Liam is an aerospace engineer, he'll test t...
# 4    Bill believes that his content management appl...
# ..                                                 ...
# 391  If Maya is a piano teacher, she'll bring her m...
# 392  Aliya believes that her scrub is in the locker...
# 393  If Aliya is a nurse and she wears her scrub to...
# 394  Either Aliya isn't a nurse, or she wears her s...
# 395  If Aliya is a nurse, she'll wear her scrub to ...
#
#                                      hypothesis gold_label     trigger  SetID  \
# 0                       Liam has a wind tunnel.          E  possessive      0
# 1                       Liam has a wind tunnel.          E  possessive      0
# 2                       Liam has a wind tunnel.          E  possessive      0
# 3                       Liam has a wind tunnel.          E  possessive      0
# 4    Bill has a content management application.          E  possessive      1
# ..                                          ...        ...         ...    ...
# 391                       Maya has a metronome.          E  possessive     97
# 392                           Aliya has scrubs.          E  possessive     98
# 393                           Aliya has scrubs.          E  possessive     98
# 394                           Aliya has scrubs.          E  possessive     98
# 395                           Aliya has scrubs.          E  possessive     98
#
#                      UID                       Trigger Words  \
# 0    type4_possessive_00                     his wind tunnel
# 1    type4_possessive_00                     his wind tunnel
# 2    type4_possessive_00                     his wind tunnel
# 3    type4_possessive_00                     his wind tunnel
# 4    type4_possessive_01  his content management application
# ..                   ...                                 ...
# 391  type4_possessive_97                       her metronome
# 392  type4_possessive_98                           her scrub
# 393  type4_possessive_98                           her scrub
# 394  type4_possessive_98                           her scrub
# 395  type4_possessive_98                           her scrub
#
#             premise_type
# 0       Attitude Premise
# 1    Conjunction Premise
# 2    Disjunction Premise
# 3                premise
# 4       Attitude Premise
# ..                   ...
# 391              premise
# 392     Attitude Premise
# 393  Conjunction Premise
# 394  Disjunction Premise
# 395              premise
#
# [396 rows x 8 columns]

# %%
test_df5a = pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type5a_final.csv',index_col=0)
test_df5a
# Out:
#                                                 premise  \
# 0     Jessica believes she'll watch a movie by Nolan...
# 1     If Jessica attends the conference and she neve...
# 2     Either Jessica doesn't attend the conference, ...
# 3     If Jessica attends the conference, she'll neve...
# 4     Emily believes she'll read a book by Dan Brown...
# ...                                                 ...
# 1595  If Betty misses the bus, she'll never cherish ...
# 1596  Zoey believes that she'll hold a student respo...
# 1597  If Zoey decides to drive and she never holds a...
# 1598  Either Zoey doesn't decide to drive, or she an...
# 1599  If Zoey decides to drive, she'll never hold a ...
#
#                                              hypothesis gold_label  \
# 0          Jessica has watched a movie by Nolan before.          E
# 1          Jessica has watched a movie by Nolan before.          E
# 2          Jessica has watched a movie by Nolan before.          E
# 3          Jessica has watched a movie by Nolan before.          E
# 4            Emily has read a book by Dan Brown before.          E
# ...                                                 ...        ...
# 1595      Betty has cherished a moment in peace before.          E
# 1596  Zoey has held a student responsible for a mist...          E
# 1597  Zoey has held a student responsible for a mist...          E
# 1598  Zoey has held a student responsible for a mist...          E
# 1599  Zoey has held a student responsible for a mist...          E
#
#          trigger  SetID                UID  \
# 0     possessive      0   type5_again_2_00
# 1     possessive      0   type5_again_2_00
# 2     possessive      0   type5_again_2_00
# 3     possessive      0   type5_again_2_00
# 4     possessive      1   type5_again_2_01
# ...          ...    ...                ...
# 1595  possessive    398  type5_again_2_398
# 1596  possessive    399  type5_again_2_399
# 1597  possessive    399  type5_again_2_399
# 1598  possessive    399  type5_again_2_399
# 1599  possessive    399  type5_again_2_399
#
#                                 Trigger Words         premise_type
# 0                        movie by Nolan again     Attitude Premise
# 1                        movie by Nolan again  Conjunction Premise
# 2                        movie by Nolan again  Disjunction Premise
# 3                        movie by Nolan again              premise
# 4                    book by Dan Brown before     Attitude Premise
# ...                                       ...                  ...
# 1595                  a moment in peace again              premise
# 1596  Student responsible for a mistake again     Attitude Premise
# 1597  Student responsible for a mistake again  Conjunction Premise
# 1598  Student responsible for a mistake again  Disjunction Premise
# 1599  Student responsible for a mistake again              premise
#
# [1600 rows x 8 columns]

# %%
test_df5p = pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type5p_final.csv',index_col=0)
test_df5p
# Out:
#                                                 premise  \
# 0         Jessica believes that her friend is upstairs.
# 1     If Jessica attends the conference and her frie...
# 2     Either Sarah doesn't attend the conference, or...
# 3     If Jessica attends the conference, her colleag...
# 4             Emily believes her best friend is nearby.
# ...                                                 ...
# 1595  If Betty misses the bus, her brother will driv...
# 1596  Zoey believes that her friends are at the conc...
# 1597  If Zoey decides to drive and her friends meet ...
# 1598  Either Zoey doesn't decide to drive, or she an...
# 1599  If Zoey decides to drive, her friends will mee...
#
#                     hypothesis gold_label     trigger  SetID  \
# 0        Jessica has a friend.          E  possessive      0
# 1        Jessica has a friend.          E  possessive      0
# 2        Jessica has a friend.          E  possessive      0
# 3        Jessica has a friend.          E  possessive      0
# 4     Emily has a best friend.          E  possessive      1
# ...                        ...        ...         ...    ...
# 1595      Betty has a brother.          E  possessive    398
# 1596         Zoey has friends.          E  possessive    399
# 1597         Zoey has friends.          E  possessive    399
# 1598         Zoey has friends.          E  possessive    399
# 1599         Zoey has friends.          E  possessive    399
#
#                          UID    Trigger Words         premise_type
# 0      type5_possessive_1_00       her friend     Attitude Premise
# 1      type5_possessive_1_00       her friend  Conjunction Premise
# 2      type5_possessive_1_00       her friend  Disjunction Premise
# 3      type5_possessive_1_00       her friend              premise
# 4      type5_possessive_1_01  her best friend     Attitude Premise
# ...                      ...              ...                  ...
# 1595  type5_possessive_1_398      her brother              premise
# 1596  type5_possessive_1_399      her friends     Attitude Premise
# 1597  type5_possessive_1_399      her friends  Conjunction Premise
# 1598  type5_possessive_1_399      her friends  Disjunction Premise
# 1599  type5_possessive_1_399      her friends              premise
#
# [1600 rows x 8 columns]

# %%
test_df = pd.concat([test_df4,test_df5a,test_df5p])
test_df
# Out:
#                                                 premise  \
# 0         Liam believes that his wind tunnel is nearby.
# 1     If Liam is an aerospace engineer and he tests ...
# 2     Either Liam isn't an aerospace engineer, or he...
# 3     If Liam is an aerospace engineer, he'll test t...
# 4     Bill believes that his content management appl...
# ...                                                 ...
# 1595  If Betty misses the bus, her brother will driv...
# 1596  Zoey believes that her friends are at the conc...
# 1597  If Zoey decides to drive and her friends meet ...
# 1598  Either Zoey doesn't decide to drive, or she an...
# 1599  If Zoey decides to drive, her friends will mee...
#
#                                       hypothesis gold_label     trigger  \
# 0                        Liam has a wind tunnel.          E  possessive
# 1                        Liam has a wind tunnel.          E  possessive
# 2                        Liam has a wind tunnel.          E  possessive
# 3                        Liam has a wind tunnel.          E  possessive
# 4     Bill has a content management application.          E  possessive
# ...                                          ...        ...         ...
# 1595                        Betty has a brother.          E  possessive
# 1596                           Zoey has friends.          E  possessive
# 1597                           Zoey has friends.          E  possessive
# 1598                           Zoey has friends.          E  possessive
# 1599                           Zoey has friends.          E  possessive
#
#       SetID                     UID                       Trigger Words  \
# 0         0     type4_possessive_00                     his wind tunnel
# 1         0     type4_possessive_00                     his wind tunnel
# 2         0     type4_possessive_00                     his wind tunnel
# 3         0     type4_possessive_00                     his wind tunnel
# 4         1     type4_possessive_01  his content management application
# ...     ...                     ...                                 ...
# 1595    398  type5_possessive_1_398                         her brother
# 1596    399  type5_possessive_1_399                         her friends
# 1597    399  type5_possessive_1_399                         her friends
# 1598    399  type5_possessive_1_399                         her friends
# 1599    399  type5_possessive_1_399                         her friends
#
#              premise_type
# 0        Attitude Premise
# 1     Conjunction Premise
# 2     Disjunction Premise
# 3                 premise
# 4        Attitude Premise
# ...                   ...
# 1595              premise
# 1596     Attitude Premise
# 1597  Conjunction Premise
# 1598  Disjunction Premise
# 1599              premise
#
# [3596 rows x 8 columns]

# %%
test_df.to_csv('part4a_all.csv')

# %%
sample_test_df = test_df5a.iloc[:8].reset_index()
sample_test_df
# Out:
#    index                                            premise  \
# 0      0  Jessica believes she'll watch a movie by Nolan...
# 1      1  If Jessica attends the conference and she neve...
# 2      2  Either Jessica doesn't attend the conference, ...
# 3      3  If Jessica attends the conference, she'll neve...
# 4      4  Emily believes she'll read a book by Dan Brown...
# 5      5  If Emily passes her driving test and she never...
# 6      6  Either Emily passes her driving test, or she a...
# 7      7  If Emily passes her driving test, she'll never...
#
#                                      hypothesis gold_label     trigger  SetID  \
# 0  Jessica has watched a movie by Nolan before.          E  possessive      0
# 1  Jessica has watched a movie by Nolan before.          E  possessive      0
# 2  Jessica has watched a movie by Nolan before.          E  possessive      0
# 3  Jessica has watched a movie by Nolan before.          E  possessive      0
# 4    Emily has read a book by Dan Brown before.          E  possessive      1
# 5    Emily has read a book by Dan Brown before.          E  possessive      1
# 6    Emily has read a book by Dan Brown before.          E  possessive      1
# 7    Emily has read a book by Dan Brown before.          E  possessive      1
#
#                 UID             Trigger Words         premise_type
# 0  type5_again_2_00      movie by Nolan again     Attitude Premise
# 1  type5_again_2_00      movie by Nolan again  Conjunction Premise
# 2  type5_again_2_00      movie by Nolan again  Disjunction Premise
# 3  type5_again_2_00      movie by Nolan again              premise
# 4  type5_again_2_01  book by Dan Brown before     Attitude Premise
# 5  type5_again_2_01  book by Dan Brown before  Conjunction Premise
# 6  type5_again_2_01  book by Dan Brown before  Disjunction Premise
# 7  type5_again_2_01  book by Dan Brown before              premise

# %%
possessive_trigger = False
test_df = sample_test_df
# test_df = test_df5a

# %%
sample_test_df
# Out:
#    index                                            premise  \
# 0      0  Jessica believes she'll watch a movie by Nolan...
# 1      1  If Jessica attends the conference and she neve...
# 2      2  Either Jessica doesn't attend the conference, ...
# 3      3  If Jessica attends the conference, she'll neve...
# 4      4  Emily believes she'll read a book by Dan Brown...
# 5      5  If Emily passes her driving test and she never...
# 6      6  Either Emily passes her driving test, or she a...
# 7      7  If Emily passes her driving test, she'll never...
#
#                                      hypothesis gold_label     trigger  SetID  \
# 0  Jessica has watched a movie by Nolan before.          E  possessive      0
# 1  Jessica has watched a movie by Nolan before.          E  possessive      0
# 2  Jessica has watched a movie by Nolan before.          E  possessive      0
# 3  Jessica has watched a movie by Nolan before.          E  possessive      0
# 4    Emily has read a book by Dan Brown before.          E  possessive      1
# 5    Emily has read a book by Dan Brown before.          E  possessive      1
# 6    Emily has read a book by Dan Brown before.          E  possessive      1
# 7    Emily has read a book by Dan Brown before.          E  possessive      1
#
#                 UID             Trigger Words         premise_type
# 0  type5_again_2_00      movie by Nolan again     Attitude Premise
# 1  type5_again_2_00      movie by Nolan again  Conjunction Premise
# 2  type5_again_2_00      movie by Nolan again  Disjunction Premise
# 3  type5_again_2_00      movie by Nolan again              premise
# 4  type5_again_2_01  book by Dan Brown before     Attitude Premise
# 5  type5_again_2_01  book by Dan Brown before  Conjunction Premise
# 6  type5_again_2_01  book by Dan Brown before  Disjunction Premise
# 7  type5_again_2_01  book by Dan Brown before              premise

# %%
test_example = [
    test_df['premise'], 
    test_df['hypothesis']
]

test_dataset = NewsDataset(
    data_list=test_example,
    tokenizer=tokenizer,
    max_length=config.max_position_embeddings, 
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=8,
    shuffle=False,
)

# %%
integrated_grad = IntegratedGradient(
    model, 
    criterion, 
    tokenizer, 
    show_progress=False,
    # encoder="bert"
)
instances = integrated_grad.saliency_interpret(test_dataloader)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %%
def reformat_output(instances):

    instances_word_gradients = []

    for instance in instances: 
        i = 0 # position counter 
        token_gradients = defaultdict(float) # dict to keep track of grad of each token     
        for token, grad in zip(instance['tokens'], instance['grad']):
            if token != '<unk>':
                token_gradients[(token,i)] += grad  # each token has its IG value added to the dict 
                i += 1
        
        token_gradients = dict(token_gradients)
        tokens = [tok[0] for tok in list(token_gradients.keys())]
        word_gradients = {}
    
        for i, token in enumerate(tokens):
            word = tokens[i]
            if word.startswith('Ġ'):
                word = word[1:]
            count = 1 
            word_gradient = token_gradients[(token,i)]
            if word in ['[SEP]','[CLS]']:
                 word_gradients[word] = word_gradient
                 continue # do not merge with next token
            while (i+1)<len(tokens) and tokens[i+1] not in string.punctuation and not tokens[i+1].startswith('Ġ') and not tokens[i+1] == '[SEP]':
                # part of same word, add gradients together and then average out 
                i += 1 # move to next word
                word += tokens[i] # concatente to restore word 
                word_gradient += token_gradients[(tokens[i],i)]
                count += 1
            # end of word 
            word_gradients[(word,i)] = word_gradient/count # averaging
        instances_word_gradients.append(word_gradients)
    
    return instances_word_gradients

# %%
def get_average_gradient(instances):
    # average gradient per token
    return [sum(instance['grad'])/len(instance['grad']) for instance in instances]

# %%
def compute_trigger_gradients(row):
    
    gradients = 0
    count = 0
    trigger_words = []

    # split phrases into individual words
    trigger_words = row['Trigger Words'].split()

    # get gradient of all words in this example
    word_gradients = row['word_gradients']
    word_gradients_words = [key[0] for key in list(word_gradients.keys())] # extracting word portion of keys
    
    word_index_mapping = {}
    for word, index in list(word_gradients.keys()):
        word_index_mapping.setdefault(word,index) # set the first value (premise value) as the index
    
    for word in trigger_words:
        if word in word_gradients_words:
            word_index = word_index_mapping[word]
            gradients += word_gradients[(word,word_index)]
            count += 1 
        elif word.lower() in word_gradients_words:
            word_index = word_index_mapping[word.lower()]
            gradients += word_gradients[(word.lower(),word_index)]
            count += 1 
        else:
            print(f"{row.name}: {word} not found!")

    # compute avg gradient of trigger tokens
    return gradients/count if count > 0 else 0

# %%
def get_predicted_label(instances):
    return [instance['label'] for instance in instances]

# %%
def compute_trigger_word_ranking(word_gradients,possessive_trigger):

    sorted_dict = dict(sorted(word_gradients.items(), key=lambda item: item[1],reverse=True))
    sorted_dict = {k: v for k,v in sorted_dict.items() if k[0] not in ['[CLS]','[SEP]'] and k[0] not in string.punctuation}
    word_gradients_df = pd.DataFrame.from_dict(sorted_dict, orient='index', columns=['Gradient'])
    word_gradients_df.index = pd.MultiIndex.from_tuples(word_gradients_df.index, names=['Word', 'Position'])
    word_gradients_df['Ranking'] = range(1, len(word_gradients_df) + 1)
    word_gradients_df['Percentile Ranking'] = word_gradients_df['Ranking'].apply(lambda x: x / len(word_gradients_df))

    word_gradients_words = [key[0] for key in list(word_gradients.keys())] # extracting word portion of keys 
    word_index_mapping = {}
    for word, index in list(word_gradients.keys()):
        word_index_mapping.setdefault(word,index) # set the first value (premise value) as the index

    key_trigger_word = ''
    if possessive_trigger:
        if 'his' in word_gradients_words:
            key_trigger_word = 'his'
        elif 'her' in word_gradients_words:
            key_trigger_word = 'her'
        elif 'their' in word_gradients_words:
            key_trigger_word = 'their'
    else:
        key_trigger_word = 'again'

    try:
        key_trigger_word_index = word_index_mapping[key_trigger_word]
        key_trigger_word_key = (f'{key_trigger_word}', key_trigger_word_index)    
        key_trigger_word_rank = word_gradients_df.loc[key_trigger_word_key]['Ranking']
        key_trigger_word_percent_rank = word_gradients_df.loc[key_trigger_word_key]['Percentile Ranking']
    except:
        key_trigger_word_rank = None 
        key_trigger_word_percent_rank = None
        print(f"Trigger word not found! - {key_trigger_word}")

    return pd.Series([key_trigger_word_rank, key_trigger_word_percent_rank])

# %%
test_df['word_gradients'] = reformat_output(instances)
test_df['average_gradient'] = get_average_gradient(instances)
test_df['trigger_gradient'] = test_df.apply(compute_trigger_gradients,axis=1)
test_df['predicted_label'] = get_predicted_label(instances)
test_df['predicted_label'] = test_df['predicted_label'].map({0:'C',1:'N',2:'E'})
test_df[['trigger_word_ranking','trigger_word_percentile_ranking']] = test_df['word_gradients'].apply(compute_trigger_word_ranking,args=(possessive_trigger,))
test_df
# Out:
#    index                                            premise  \
# 0      0  Jessica believes she'll watch a movie by Nolan...
# 1      1  If Jessica attends the conference and she neve...
# 2      2  Either Jessica doesn't attend the conference, ...
# 3      3  If Jessica attends the conference, she'll neve...
# 4      4  Emily believes she'll read a book by Dan Brown...
# 5      5  If Emily passes her driving test and she never...
# 6      6  Either Emily passes her driving test, or she a...
# 7      7  If Emily passes her driving test, she'll never...
#
#                                      hypothesis gold_label     trigger  SetID  \
# 0  Jessica has watched a movie by Nolan before.          E  possessive      0
# 1  Jessica has watched a movie by Nolan before.          E  possessive      0
# 2  Jessica has watched a movie by Nolan before.          E  possessive      0
# 3  Jessica has watched a movie by Nolan before.          E  possessive      0
# 4    Emily has read a book by Dan Brown before.          E  possessive      1
# 5    Emily has read a book by Dan Brown before.          E  possessive      1
# 6    Emily has read a book by Dan Brown before.          E  possessive      1
# 7    Emily has read a book by Dan Brown before.          E  possessive      1
#
#                 UID             Trigger Words         premise_type  \
# 0  type5_again_2_00      movie by Nolan again     Attitude Premise
# 1  type5_again_2_00      movie by Nolan again  Conjunction Premise
# 2  type5_again_2_00      movie by Nolan again  Disjunction Premise
# 3  type5_again_2_00      movie by Nolan again              premise
# 4  type5_again_2_01  book by Dan Brown before     Attitude Premise
# 5  type5_again_2_01  book by Dan Brown before  Conjunction Premise
# 6  type5_again_2_01  book by Dan Brown before  Disjunction Premise
# 7  type5_again_2_01  book by Dan Brown before              premise
#
#                                       word_gradients  average_gradient  \
# 0  {('Jessica', 0): 0.06825824081897736, ('believ...          0.001953
# 1  {('If', 0): 0.008264544419944286, ('Jessica', ...          0.001953
# 2  {('Either', 0): 0.003731327597051859, ('Jessic...          0.001953
# 3  {('If', 0): 0.010709958150982857, ('Jessica', ...          0.001953
# 4  {('Emily', 0): 0.009556190110743046, ('believe...          0.001953
# 5  {('If', 0): 0.016956517472863197, ('Emily', 1)...          0.001953
# 6  {('Either', 0): 0.013360684737563133, ('Emily'...          0.001953
# 7  {('If', 0): 0.0004079224599990994, ('Emily', 1...          0.001953
#
#    trigger_gradient predicted_label  trigger_word_ranking  \
# 0          0.042233               E                  17.0
# 1          0.004882               E                  23.0
# 2          0.024543               E                   3.0
# 3          0.046317               E                   2.0
# 4          0.032351               E                   2.0
# 5          0.011878               E                   5.0
# 6          0.027218               E                  28.0
# 7          0.041452               E                   8.0
#
#    trigger_word_percentile_ranking
# 0                         0.894737
# 1                         0.884615
# 2                         0.111111
# 3                         0.086957
# 4                         0.095238
# 5                         0.172414
# 6                         1.000000
# 7                         0.307692

# %%
test_df.to_csv('part4a_type5a_roberta_results_new.csv')
