# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df1 =  pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type4_final.csv')
df1['type'] = 'type4'
df2 =  pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type5a_final.csv')
df2['type'] = 'type5A'
df3 =  pd.read_csv('/kaggle/input/confer-extension/Part4A_Dataset/part4a_type5p_final.csv')
df3['type'] = 'type5P'

# %%
df = pd.concat([df1,df2,df3])
df
# Out:
#       Unnamed: 0                                            premise  \
# 0              0      Liam believes that his wind tunnel is nearby.
# 1              1  If Liam is an aerospace engineer and he tests ...
# 2              2  Either Liam isn't an aerospace engineer, or he...
# 3              3  If Liam is an aerospace engineer, he'll test t...
# 4              4  Bill believes that his content management appl...
# ...          ...                                                ...
# 1595        1595  If Betty misses the bus, her brother will driv...
# 1596        1596  Zoey believes that her friends are at the conc...
# 1597        1597  If Zoey decides to drive and her friends meet ...
# 1598        1598  Either Zoey doesn't decide to drive, or she an...
# 1599        1599  If Zoey decides to drive, her friends will mee...
#
#                                       hypothesis gold_label     trigger  \
# 0                        Liam has a wind tunnel.          E  possessive
# ...

# %%
pd.DataFrame(df[['type','premise_type']].value_counts())
# Out:
#                             count
# type   premise_type
# type5A Attitude Premise       400
#        Conjunction Premise    400
#        Disjunction Premise    400
#        premise                400
# type5P Attitude Premise       400
#        Conjunction Premise    400
#        Disjunction Premise    400
#        premise                400
# type4  Attitude Premise        99
#        Conjunction Premise     99
#        Disjunction Premise     99
#        premise                 99

# %%
df1 = pd.read_excel('/kaggle/input/confer-extension/Part4B_Dataset/4B_Type4.xlsx')
df1['sentence type'] = 'type4'
df2 = pd.read_excel('/kaggle/input/confer-extension/Part4B_Dataset/4B_Type5A.xlsx')
df2['sentence type'] = 'type5A'
df3 = pd.read_excel('/kaggle/input/confer-extension/Part4B_Dataset/4B_Type5P.xlsx')
df3['sentence type'] = 'type5P'

# %%
pd.read_excel('/kaggle/input/confer-extension/Part4B_Dataset/4B_Type5A.xlsx')
# Out:
#                                                 premise  \
# 0     If Jessica attends the conference, she'll neve...
# 1     If Emily passes her driving test, she'll never...
# 2     If Scarlett finishes her work early, she'll ne...
# 3     If Chloe finishes her work early, she'll never...
# 4     If Charlotte passes her driving test, she'll n...
# ...                                                 ...
# 1595  If Dorothy's car breaks down, she'll never obt...
# 1596  If Susan finishes her work early, she'll never...
# 1597  If Margaret finishes work early, she'll never ...
# 1598  If Betty misses the bus, she'll never cherish ...
# 1599  If Zoey decides to drive, she'll never hold a ...
#
#                                              hypothesis gold_label trigger  \
# 0          Jessica has watched a movie by Nolan before.          E   again
# 1            Emily has read a book by Dan Brown before.          E   again
# ...

# %%
df = pd.concat([df1,df2,df3])
df
# Out:
#                                                 premise  \
# 0     If Liam is an aerospace engineer, he'll test t...
# 1     If Bill is a content strategist, he'll manage ...
# 2     If Steve is a conservation officer, he'll set ...
# 3     If Matt is a scuba diver, he'll bring his wets...
# 4     If Noah is a pastry chef, he'll pipe frosting ...
# ...                                                 ...
# 1195  If Dorothy car breaks down, Tina's friend will...
# 1196  If Susan finishes his work early, Tina's frien...
# 1197  If Margaret finishes work early, Tina's friend...
# 1198  If Betty misses the bus, Tina's friend will dr...
# 1199  If Zoey decides to drive, Tina's friend will m...
#
#                                       hypothesis gold_label     trigger  \
# 0                        Liam has a wind tunnel.          E  possessive
# 1     Bill has a content management application.          E  possessive
# 2                     Steve has a wildlife trap.          E  possessive
# ...

# %%
pd.DataFrame(df[['sentence type','type']].value_counts())
# Out:
#                                 count
# sentence type type
# type5A        no again            400
#               related             400
#               somewhat_related    400
#               unrelated           400
# type5P        related             400
#               somewhat_related    400
#               unrelated           400
# type4         related              99
#               somewhat_related     99
#               unrelated            99

# %%
df1 = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type4_final.csv')
df1['sentence type'] = 'type4'
df2 = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type5A_final.csv')
df2['sentence type'] = 'type5A'
df3 = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type5P_final.csv')
df3['sentence type'] = 'type5P'

# %%
df = pd.concat([df1,df2,df3])
df
# Out:
#      Unnamed: 0                                            premise  \
# 0             0  If Alexander is an electrical technician, he'l...
# 1             1  If Alexander is an electrical technician, he'l...
# 2             2  If Alexander is an electrical technician, he'l...
# 3             3  If Ali is a firefighter, he'll borrow us his f...
# 4             4  If Ali is a firefighter, he'll pick his fireho...
# ..          ...                                                ...
# 795         795  If Margaret finishes work early, her wife will...
# 796         796  If Betty misses the train, her brother will dr...
# 797         797  If Betty misses the train, her brother will ma...
# 798         798  If Zoey decides to bike, her friends will meet...
# 799         799  If Zoey decides to bike, her friends will pain...
#
#                               hypothesis gold_label     trigger  SetID  \
# 0    Alexander has an insulation tester.          E  possessive      0
# ...

# %%
pd.DataFrame(df[['sentence type','premise_type']].value_counts())
# Out:
#                                 count
# sentence type premise_type
# type5A        related             400
#               unrelated           400
# type5P        related             400
#               unrelated           400
# type4         related              99
#               somewhat_related     99
#               unrelated            99
