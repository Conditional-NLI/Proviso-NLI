# %%
import pandas as pd
import pickle

from dataset import NewsDataset

from smooth_gradient import SmoothGradient
from integrated_gradient import IntegratedGradient

from collections import defaultdict
import string

import torch
from torch import nn
from torch.utils.data import DataLoader
from transformers import DistilBertConfig, DistilBertTokenizer
from transformers import RobertaConfig

from IPython.display import display, HTML

from transformers import TrainingArguments, Trainer, AutoTokenizer, AutoModelForSequenceClassification, DataCollatorWithPadding
# Out:
# 2025-08-07 22:51:08.678732: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754607069.065717      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754607069.180396      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from huggingface_hub import login

login(new_session=False, # Won’t request token if one is already saved on machine
write_permission=True, # Requires a token with write permission
token="", # The name of your token
add_to_git_credential=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in 'login': write_permission. Will not be supported from version '1.0'.
#
# Fine-grained tokens added complexity to the permissions, making it irrelevant to check if a token has 'write' access.
#   warnings.warn(message, FutureWarning)
# Token has not been saved to git credential helper.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# Run the following command in your terminal in case you want to set the 'store' credential helper as default.
#
# git config --global credential.helper store
#
# Read https://git-scm.com/book/en/v2/Git-Tools-Credential-Storage for more details.

# %%
checkpoint = "FacebookAI/roberta-large-mnli"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint, num_labels=3)
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# Some weights of the model checkpoint at FacebookAI/roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
config = RobertaConfig()
batch_size = 2
criterion = nn.CrossEntropyLoss()
config.max_position_embeddings
# Out:
# 512

# %% [markdown]
# ## Running on Dataset

# %%
from datasets import load_dataset, concatenate_datasets
import json
import ast

# %%
test_df4 = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type4_final.csv',index_col=0)
test_df4
# Out:
#                                                premise  \
# 0    If Alexander is an electrical technician, he'l...
# 1    If Alexander is an electrical technician, he'l...
# 2    If Alexander is an electrical technician, he'l...
# 3    If Ali is a firefighter, he'll borrow us his f...
# 4    If Ali is a firefighter, he'll pick his fireho...
# ..                                                 ...
# 292  If the girl is a yoga teacher, she'll grab her...
# 293  If the girl is a yoga teacher, she'll use her ...
# 294  If the king is a teacher, he'll pack his suitc...
# 295  If the king is a teacher, he'll pack his suitc...
# 296  If the king is a teacher, he'll use his suitca...
#
#                               hypothesis gold_label     trigger  SetID  \
# 0    Alexander has an insulation tester.          E  possessive      0
# 1    Alexander has an insulation tester.          E  possessive      0
# 2    Alexander has an insulation tester.          E  possessive      0
# 3                    Ali has a firehose.          E  possessive      1
# 4                    Ali has a firehose.          E  possessive      1
# ..                                   ...        ...         ...    ...
# 292             The girl has yoga pants.          E  possessive     97
# 293             The girl has yoga pants.          E  possessive     97
# 294             The king has a suitcase.          E  possessive     98
# 295             The king has a suitcase.          E  possessive     98
# 296             The king has a suitcase.          E  possessive     98
#
#                      UID          Trigger Words      premise_type
# 0    type4_possessive_00  his insulation tester         unrelated
# 1    type4_possessive_00  his insulation tester  somewhat_related
# 2    type4_possessive_00  his insulation tester           related
# 3    type4_possessive_01           his firehose  somewhat_related
# 4    type4_possessive_01           his firehose         unrelated
# ..                   ...                    ...               ...
# 292  type4_possessive_97         her yoga pants         unrelated
# 293  type4_possessive_97         her yoga pants           related
# 294  type4_possessive_98           his suitcase         unrelated
# 295  type4_possessive_98           his suitcase  somewhat_related
# 296  type4_possessive_98           his suitcase           related
#
# [297 rows x 8 columns]

# %%
test_df5a = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type5A_final.csv',index_col=0)
test_df5a
# Out:
#                                                premise  \
# 0    If Jessica attends a movie festival, she'll ne...
# 1    If Jessica attends the conference, she'll neve...
# 2    If Emily finishes a mystery novel, she'll neve...
# 3    If Emily passes her driving test, she'll never...
# 4    If Scarlett bakes a Swedish pastry, she'll nev...
# ..                                                 ...
# 795  If Margaret finishes work early, she'll never ...
# 796  If Betty cherishes quiet time after missing th...
# 797  If Betty misses the bus, she'll never cherish ...
# 798  If Zoey holds a student responsible when drivi...
# 799  If Zoey decides to drive, she'll never hold a ...
#
#                                             hypothesis gold_label trigger  \
# 0         Jessica has watched a movie by Nolan before.          E   again
# 1         Jessica has watched a movie by Nolan before.          E   again
# 2           Emily has read a book by Dan Brown before.          E   again
# 3           Emily has read a book by Dan Brown before.          E   again
# 4    Scarlett has eaten a traditional Swedish dish ...          E   again
# ..                                                 ...        ...     ...
# 795      Margaret has managed to keep a secret before.          E   again
# 796      Betty has cherished a moment in peace before.          E   again
# 797      Betty has cherished a moment in peace before.          E   again
# 798  Zoey has held a student responsible for a mist...          E   again
# 799  Zoey has held a student responsible for a mist...          E   again
#
#      SetID               UID                             Trigger Words  \
# 0        0   type5a_again_00                          a movie festival
# 1        0   type5a_again_00                    attends the conference
# 2        1   type5a_again_01                  finishes a mystery novel
# 3        1   type5a_again_01                   passes her driving test
# 4        2   type5a_again_02                    bakes a Swedish pastry
# ..     ...               ...                                       ...
# 795    397  type5a_again_397                       finishes work early
# 796    398  type5a_again_398                cherishes quiet time after
# 797    398  type5a_again_398                            misses the bus
# 798    399  type5a_again_399  holds a student responsible when driving
# 799    399  type5a_again_399                          decides to drive
#
#     premise_type
# 0        related
# 1      unrelated
# 2        related
# 3      unrelated
# 4        related
# ..           ...
# 795    unrelated
# 796      related
# 797    unrelated
# 798      related
# 799    unrelated
#
# [800 rows x 8 columns]

# %%
test_df5p = pd.read_csv('/kaggle/input/confer-extension/Updated_Part5_Dataset/Part5_Type5P_final.csv',index_col=0)
test_df5p
# Out:
#                                                premise  \
# 0    If Jessica attends the conference, her colleag...
# 1    If Jessica attends the conference, her colleag...
# 2    If Emily passes her driving test, her best fri...
# 3    If Emily passes her driving test, her best fri...
# 4    If Scarlett finishes her chores early, her hus...
# ..                                                 ...
# 795  If Margaret finishes work early, her wife will...
# 796  If Betty misses the train, her brother will dr...
# 797  If Betty misses the train, her brother will ma...
# 798  If Zoey decides to bike, her friends will meet...
# 799  If Zoey decides to bike, her friends will pain...
#
#                    hypothesis gold_label     trigger  SetID  \
# 0    Jessica has a colleague.          E  possessive      0
# 1    Jessica has a colleague.          E  possessive      0
# 2    Emily has a best friend.          E  possessive      1
# 3    Emily has a best friend.          E  possessive      1
# 4     Scarlett has a husband.          E  possessive      2
# ..                        ...        ...         ...    ...
# 795      Margaret has a wife.          E  possessive    397
# 796      Betty has a brother.          E  possessive    398
# 797      Betty has a brother.          E  possessive    398
# 798         Zoey has friends.          E  possessive    399
# 799         Zoey has friends.          E  possessive    399
#
#                        UID    Trigger Words premise_type
# 0     type5p_possessive_00    her colleague      related
# 1     type5p_possessive_00    her colleague    unrelated
# 2     type5p_possessive_01  her best friend      related
# 3     type5p_possessive_01  her best friend    unrelated
# 4     type5p_possessive_02      her husband      related
# ..                     ...              ...          ...
# 795  type5p_possessive_397         his wife    unrelated
# 796  type5p_possessive_398      her brother      related
# 797  type5p_possessive_398      her brother    unrelated
# 798  type5p_possessive_399      her friends      related
# 799  type5p_possessive_399      her friends    unrelated
#
# [800 rows x 8 columns]

# %%
test_df = pd.concat([test_df4,test_df5a,test_df5p]).reset_index()
test_df
# Out:
#       index                                            premise  \
# 0         0  If Alexander is an electrical technician, he'l...
# 1         1  If Alexander is an electrical technician, he'l...
# 2         2  If Alexander is an electrical technician, he'l...
# 3         3  If Ali is a firefighter, he'll borrow us his f...
# 4         4  If Ali is a firefighter, he'll pick his fireho...
# ...     ...                                                ...
# 1892    795  If Margaret finishes work early, her wife will...
# 1893    796  If Betty misses the train, her brother will dr...
# 1894    797  If Betty misses the train, her brother will ma...
# 1895    798  If Zoey decides to bike, her friends will meet...
# 1896    799  If Zoey decides to bike, her friends will pain...
#
#                                hypothesis gold_label     trigger  SetID  \
# 0     Alexander has an insulation tester.          E  possessive      0
# 1     Alexander has an insulation tester.          E  possessive      0
# 2     Alexander has an insulation tester.          E  possessive      0
# 3                     Ali has a firehose.          E  possessive      1
# 4                     Ali has a firehose.          E  possessive      1
# ...                                   ...        ...         ...    ...
# 1892                 Margaret has a wife.          E  possessive    397
# 1893                 Betty has a brother.          E  possessive    398
# 1894                 Betty has a brother.          E  possessive    398
# 1895                    Zoey has friends.          E  possessive    399
# 1896                    Zoey has friends.          E  possessive    399
#
#                         UID          Trigger Words      premise_type
# 0       type4_possessive_00  his insulation tester         unrelated
# 1       type4_possessive_00  his insulation tester  somewhat_related
# 2       type4_possessive_00  his insulation tester           related
# 3       type4_possessive_01           his firehose  somewhat_related
# 4       type4_possessive_01           his firehose         unrelated
# ...                     ...                    ...               ...
# 1892  type5p_possessive_397               his wife         unrelated
# 1893  type5p_possessive_398            her brother           related
# 1894  type5p_possessive_398            her brother         unrelated
# 1895  type5p_possessive_399            her friends           related
# 1896  type5p_possessive_399            her friends         unrelated
#
# [1897 rows x 9 columns]

# %%
sample_test_df = test_df5a.iloc[:4].reset_index()
sample_test_df
# Out:
#    index                                            premise  \
# 0      0  If Jessica attends a movie festival, she'll ne...
# 1      1  If Jessica attends the conference, she'll neve...
# 2      2  If Emily finishes a mystery novel, she'll neve...
# 3      3  If Emily passes her driving test, she'll never...
#
#                                      hypothesis gold_label trigger  SetID  \
# 0  Jessica has watched a movie by Nolan before.          E   again      0
# 1  Jessica has watched a movie by Nolan before.          E   again      0
# 2    Emily has read a book by Dan Brown before.          E   again      1
# 3    Emily has read a book by Dan Brown before.          E   again      1
#
#                UID             Trigger Words premise_type
# 0  type5a_again_00          a movie festival      related
# 1  type5a_again_00    attends the conference    unrelated
# 2  type5a_again_01  finishes a mystery novel      related
# 3  type5a_again_01   passes her driving test    unrelated

# %%
possessive_trigger = False
test_df = sample_test_df
# test_df = test_df

# %%
test_example = [
    test_df['premise'], 
    test_df['hypothesis']
]

test_dataset = NewsDataset(
    data_list=test_example,
    tokenizer=tokenizer,
    max_length=256, 
)

test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False,
)

# %%
integrated_grad = IntegratedGradient(
    model, 
    criterion, 
    tokenizer, 
    show_progress=False,
    # encoder="bert"
)
instances = integrated_grad.saliency_interpret(test_dataloader)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)

# %%
def reformat_output(instances):

    instances_word_gradients = []

    for instance in instances: 
        i = 0 # position counter 
        token_gradients = defaultdict(float) # dict to keep track of grad of each token     
        for token, grad in zip(instance['tokens'], instance['grad']):
            if token != '<unk>':
                token_gradients[(token,i)] += grad  # each token has its IG value added to the dict 
                i += 1
        
        token_gradients = dict(token_gradients)
        tokens = [tok[0] for tok in list(token_gradients.keys())]
        word_gradients = {}
    
        for i, token in enumerate(tokens):
            word = tokens[i]
            if word.startswith('Ġ'):
                word = word[1:]
            count = 1 
            word_gradient = token_gradients[(token,i)]
            if word in ['[SEP]','[CLS]']:
                 word_gradients[word] = word_gradient
                 continue # do not merge with next token
            while (i+1)<len(tokens) and tokens[i+1] not in string.punctuation and not tokens[i+1].startswith('Ġ') and not tokens[i+1] == '[SEP]':
                # part of same word, add gradients together and then average out 
                i += 1 # move to next word
                word += tokens[i] # concatente to restore word 
                word_gradient += token_gradients[(tokens[i],i)]
                count += 1
            # end of word 
            word_gradients[(word,i)] = word_gradient/count # averaging
        instances_word_gradients.append(word_gradients)
    
    return instances_word_gradients

# %%
def get_average_gradient(instances):
    # average gradient per token
    return [sum(instance['grad'])/len(instance['grad']) for instance in instances]

# %%
def compute_trigger_gradients(row):
    
    gradients = 0
    count = 0
    trigger_words = []

    # split phrases into individual words
    trigger_words = row['Trigger Words'].split()

    # get gradient of all words in this example
    word_gradients = row['word_gradients']
    word_gradients_words = [key[0] for key in list(word_gradients.keys())] # extracting word portion of keys
    
    word_index_mapping = {}
    for word, index in list(word_gradients.keys()):
        word_index_mapping.setdefault(word,index) # set the first value (premise value) as the index
    
    for word in trigger_words:
        if word in word_gradients_words:
            word_index = word_index_mapping[word]
            gradients += word_gradients[(word,word_index)]
            count += 1 
        elif word.lower() in word_gradients_words:
            word_index = word_index_mapping[word.lower()]
            gradients += word_gradients[(word.lower(),word_index)]
            count += 1 
        else:
            print(f"{row.name}: {word} not found!")

    # compute avg gradient of trigger tokens
    return gradients/count if count > 0 else 0

# %%
def get_predicted_label(instances):
    return [instance['label'] for instance in instances]

# %%
def compute_trigger_word_ranking(word_gradients,possessive_trigger):

    sorted_dict = dict(sorted(word_gradients.items(), key=lambda item: item[1],reverse=True))
    sorted_dict = {k: v for k,v in sorted_dict.items() if k[0] not in ['[CLS]','[SEP]'] and k[0] not in string.punctuation}
    word_gradients_df = pd.DataFrame.from_dict(sorted_dict, orient='index', columns=['Gradient'])
    word_gradients_df.index = pd.MultiIndex.from_tuples(word_gradients_df.index, names=['Word', 'Position'])
    word_gradients_df['Ranking'] = range(1, len(word_gradients_df) + 1)
    word_gradients_df['Percentile Ranking'] = word_gradients_df['Ranking'].apply(lambda x: x / len(word_gradients_df))

    word_gradients_words = [key[0] for key in list(word_gradients.keys())] # extracting word portion of keys 
    word_index_mapping = {}
    for word, index in list(word_gradients.keys()):
        word_index_mapping.setdefault(word,index) # set the first value (premise value) as the index

    key_trigger_word = ''
    if possessive_trigger:
        if 'his' in word_gradients_words:
            key_trigger_word = 'his'
        elif 'her' in word_gradients_words:
            key_trigger_word = 'her'
        elif 'their' in word_gradients_words:
            key_trigger_word = 'their'
    else:
        key_trigger_word = 'again'

    try:
        key_trigger_word_index = word_index_mapping[key_trigger_word]
        key_trigger_word_key = (f'{key_trigger_word}', key_trigger_word_index)    
        key_trigger_word_rank = word_gradients_df.loc[key_trigger_word_key]['Ranking']
        key_trigger_word_percent_rank = word_gradients_df.loc[key_trigger_word_key]['Percentile Ranking']
    except:
        key_trigger_word_rank = None 
        key_trigger_word_percent_rank = None
        print(f"Trigger word not found! - {key_trigger_word}")

    return pd.Series([key_trigger_word_rank, key_trigger_word_percent_rank])

# %%
test_df['word_gradients'] = reformat_output(instances)
test_df['average_gradient'] = get_average_gradient(instances)
test_df['trigger_gradient'] = test_df.apply(compute_trigger_gradients,axis=1)
test_df['predicted_label'] = get_predicted_label(instances)
test_df['predicted_label'] = test_df['predicted_label'].map({0:'C',1:'N',2:'E'})
test_df[['trigger_word_ranking','trigger_word_percentile_ranking']] = test_df['word_gradients'].apply(compute_trigger_word_ranking,args=(possessive_trigger,))
test_df
# Out:
#    index                                            premise  \
# 0      0  If Jessica attends a movie festival, she'll ne...
# 1      1  If Jessica attends the conference, she'll neve...
# 2      2  If Emily finishes a mystery novel, she'll neve...
# 3      3  If Emily passes her driving test, she'll never...
#
#                                      hypothesis gold_label trigger  SetID  \
# 0  Jessica has watched a movie by Nolan before.          E   again      0
# 1  Jessica has watched a movie by Nolan before.          E   again      0
# 2    Emily has read a book by Dan Brown before.          E   again      1
# 3    Emily has read a book by Dan Brown before.          E   again      1
#
#                UID             Trigger Words premise_type  \
# 0  type5a_again_00          a movie festival      related
# 1  type5a_again_00    attends the conference    unrelated
# 2  type5a_again_01  finishes a mystery novel      related
# 3  type5a_again_01   passes her driving test    unrelated
#
#                                       word_gradients  average_gradient  \
# 0  {('If', 0): 0.0047697569243609905, ('Jessica',...          0.003906
# 1  {('If', 0): 0.005400823429226875, ('Jessica', ...          0.003906
# 2  {('If', 0): 0.00400768406689167, ('Emily', 1):...          0.003906
# 3  {('If', 0): 0.0033750194124877453, ('Emily', 1...          0.003906
#
#    trigger_gradient predicted_label  trigger_word_ranking  \
# 0          0.020878               E                   1.0
# 1          0.006470               E                   1.0
# 2          0.015527               E                  23.0
# 3          0.015264               E                  24.0
#
#    trigger_word_percentile_ranking
# 0                         0.041667
# 1                         0.043478
# 2                         0.884615
# 3                         0.923077

# %%
test_df.to_csv('part1_part5_deberta_results.csv')

# %%
coloder_string, instance = integrated_grad.colorize(instances[0])
display(HTML(coloder_string))
# Out:
# <span class="barcode"; style="color: black; background-color: #a6cee4"> <unk></span><span class="barcode"; style="color: black; background-color: #f1f7fd"> If</span><span class="barcode"; style="color: black; background-color: #e7f0fa"> ĠJessica</span><span class="barcode"; style="color: black; background-color: #b7d4ea"> Ġattends</span><span class="barcode"; style="color: black; background-color: #d4e4f4"> Ġa</span><span class="barcode"; style="color: black; background-color: #cee0f2"> Ġmovie</span><span class="barcode"; style="color: black; background-color: #eaf3fb"> Ġfestival</span><span class="barcode"; style="color: black; background-color: #125ea6"> ,</span><span class="barcode"; style="color: black; background-color: #eef5fc"> Ġshe</span><span class="barcode"; style="color: black; background-color: #f3f8fe"> 'll</span><span class="barcode"; style="color: black; background-color: #e7f1fa"> Ġnever</span><span class="barcode"; style="color: black; background-color: #68acd5"> Ġwatch</span><span class="barcode"; style="color: black; background-color: #f6faff"> Ġa</span><span class="barcode"; style="color: black; background-color: #c3daee"> Ġmovie</span><span class="barcode"; style="color: black; background-color: #e5eff9"> Ġby</span><span class="barcode"; style="color: black; background-color: #eef5fc"> ĠNolan</span><span class="barcode"; style="color: black; background-color: #08306b"> Ġagain</span><span class="barcode"; style="color: black; background-color: #d0e2f2"> .</span><span class="barcode"; style="color: black; background-color: #f4f9fe"> <unk></span><span class="barcode"; style="color: black; background-color: #d6e5f4"> Jessica</span><span class="barcode"; style="color: black; background-color: #f1f7fd"> Ġhas</span><span class="barcode"; style="color: black; background-color: #d5e5f4"> Ġwatched</span><span class="barcode"; style="color: black; background-color: #74b3d8"> Ġa</span><span class="barcode"; style="color: black; background-color: #4b98ca"> Ġmovie</span><span class="barcode"; style="color: black; background-color: #63a8d3"> Ġby</span><span class="barcode"; style="color: black; background-color: #d8e7f5"> ĠNolan</span><span class="barcode"; style="color: black; background-color: #d2e3f3"> Ġbefore</span><span class="barcode"; style="color: black; background-color: #7cb7da"> .</span><span class="barcode"; style="color: black; background-color: #ddeaf7"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-color: #f7fbff"> <unk></span><span class="barcode"; style="color: black; background-colo ...
